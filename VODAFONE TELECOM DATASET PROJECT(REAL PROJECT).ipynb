# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\DELL\\Downloads\\telecom_churn_data - telecom_churn_data1.csv")

# %%
data.head()
# Out:
#   state  account length  area code     phone international plan  \
# 0    KS             128        415  382-4657                 no
# 1    OH             107        415  371-7191                 no
# 2    NJ             137        415  358-1921                 no
# 3    OH              84        408  375-9999                yes
# 4    OK              75        415  330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data.isnull().sum()
# Out:
# state                     0
# account length            0
# area code                 0
#  phone                    0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.replace({"yes":1,"no":0},inplace=True)

# %%
data.head()
# Out:
#   state  account length  area code     phone  international plan  \
# 0    KS             128        415  382-4657                   0
# 1    OH             107        415  371-7191                   0
# 2    NJ             137        415  358-1921                   0
# 3    OH              84        408  375-9999                   1
# 4    OK              75        415  330-6626                   1
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data["churn"]=data["churn"].map(lambda x : x.rstrip("."))

# %%
data.head()
# Out:
#   state  account length  area code     phone  international plan  \
# 0    KS             128        415  382-4657                   0
# 1    OH             107        415  371-7191                   0
# 2    NJ             137        415  358-1921                   0
# 3    OH              84        408  375-9999                   1
# 4    OK              75        415  330-6626                   1
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data["churn"].replace({"True":1,"False":0},inplace=True)

# %%
data.head()
# Out:
#   state  account length  area code     phone  international plan  \
# 0    KS             128        415  382-4657                   0
# 1    OH             107        415  371-7191                   0
# 2    NJ             137        415  358-1921                   0
# 3    OH              84        408  375-9999                   1
# 4    OK              75        415  330-6626                   1
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
print(data.dtypes)
# Out:
# state                      object
# account length              int64
# area code                   int64
#  phone                     object
# international plan          int64
# voice mail plan             int64
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes        object
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                       int64
# dtype: object

# %%
data["churn"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
print(data.churn.value_counts())
# Out:
# 0    3961
# 1     656
# Name: churn, dtype: int64

# %%
data["churn"].value_counts().plot.pie(explode=[0.05,0.05],autopct="%1.1f%%",startangle=90,shadow=True,labels=["NOT CHURNED","CHURNED"],figsize=(6,6))
plt.title("Pie Chart for Churn",size=10)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"]=[7.50,3.50]
plt.rcParams["figure.autolayout"]=True

labels=["NOT CHURNED","CHURNED"]
sizes=["85.8","14.2"]
colors=["red","blue"]

patches, texts = plt.pie(sizes,colors=colors,shadow=True,startangle=90)
plt.legend(patches,labels,loc="center")
plt.axis("equal")

plt.show()

# %%
x=data["churn"].value_counts().values

# %%
x
# Out:
# array([3961,  656], dtype=int64)

# %%
my_labels=["Not churned customer","churned customer"]

# %%
my_labels
# Out:
# ['Not churned customer', 'churned customer']

# %%
my_explode=(0,0.2)

# %%
my_explode
# Out:
# (0, 0.2)

# %%
plt.pie(x,labels=my_labels,autopct="%1.1f%%",explode=my_explode,shadow=True,radius=2.0,colors=["red","green"],counterclock=True,startangle=45)
circle = plt.Circle( (0,0),1,color="white")
p=plt.gcf()
p.gca().add_artist(circle)
plt.title("Donut Plot for Churn")
plt.show()

# %%
sns.set(rc={"figure.figsize":(20,8)})
sns.countplot(x="state",hue="churn",data=data)
plt.show()

# %%
state_data = pd.crosstab(data["state"],data["churn"])
state_data["Percentage_churn"] = state_data.apply(lambda x : x[1]*100/(x[0]+x[1]),axis=1)
print(state_data)
# Out:
# churn    0   1  Percentage_churn
# state
# AK      64   5          7.246377
# AL     104  10          8.771930
# AR      62  15         19.480519
# AZ      74   7          8.641975
# CA      31  13         29.545455
# CO      81  10         10.989011
# CT      78  14         15.217391
# DC      73   9         10.975610
# DE      75  14         15.730337
# FL      73  12         14.117647
# GA      67  10         12.987013
# HI      74   5          6.329114
# IA      59   6          9.230769
# ID      97  13         11.818182
# IL      72   7          8.860759
# IN      76  13         14.606742
# KS      78  18         18.750000
# KY      77  13         14.444444
# LA      66   7          9.589041
# MA      83  14         14.432990
# MD      72  20         21.739130
# ME      77  18         18.947368
# MI      81  17         17.346939
# MN      94  18         16.071429
# MO      73  11         13.095238
# MS      75  16         17.582418
# MT      73  19         20.652174
# ...

# %%
data.groupby(['state'])["churn"].mean().sort_values(ascending=False).head(10)
# Out:
# state
# CA    0.295455
# WA    0.235955
# NJ    0.235849
# TX    0.228571
# MD    0.217391
# MT    0.206522
# AR    0.194805
# SC    0.192771
# NV    0.191011
# ME    0.189474
# Name: churn, dtype: float64

# %%
area_code_data = pd.crosstab(data["area code"],data["churn"])
area_code_data["Percentage_Churn"] = area_code_data.apply(lambda x : x[1]*100/(x[0]+x[1]),axis=1)
print(area_code_data)
# Out:
# churn         0    1  Percentage_Churn
# area code
# 408         996  165         14.211886
# 415        1981  318         13.832101
# 510         984  173         14.952463

# %%
sns.set(rc={"figure.figsize":(10,5)})
sns.countplot(x="area code",hue="churn",data=data)
plt.show()

# %%
data['area code'].value_counts()
# Out:
# 415    2299
# 408    1161
# 510    1157
# Name: area code, dtype: int64

# %%
churn_data = data[data["churn"]==bool(True)]
not_churn_data = data[data["churn"]==bool(False)]

# %%
sns.distplot(data["account length"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='account length', ylabel='Density'>

# %%
sns.distplot(data['account length'],color = "yellow",label="all")
sns.distplot(churn_data["account length"],color = "red",hist=False,label="churned")
sns.distplot(not_churn_data["account length"],color = "green",hist=False,label="Not Churned")
plt.legend()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
data["international plan"].value_counts()
# Out:
# 0    4171
# 1     446
# Name: international plan, dtype: int64

# %%
data["international plan"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
international_plan_data = pd.crosstab(data["international plan"],data["churn"])
international_plan_data["Percentage Churn"] = international_plan_data.apply(lambda x : x[1]*100/(x[0]+x[1]),axis = 1)
print(international_plan_data)
# Out:
# churn                  0    1  Percentage Churn
# international plan
# 0                   3701  470         11.268281
# 1                    260  186         41.704036

# %%
x=data["voice mail plan"].value_counts().values

# %%
x
# Out:
# array([3381, 1236], dtype=int64)

# %%
my_labels=["NO","YES"]

# %%
my_labels
# Out:
# ['NO', 'YES']

# %%
explode=[0,0.1]

# %%
plt.pie(x,labels=my_labels,autopct="%1.1f%%",explode=explode,shadow=True,startangle=45,counterclock=True,colors=["red","green"])
plt.title("VOICE MAIL DATA",size=20)
plt.show()

# %%
data["number vmail messages"].unique()
# Out:
# array([25, 26,  0, 24, 37, 27, 33, 39, 30, 41, 28, 34, 46, 29, 35, 21, 32,
#        42, 36, 22, 23, 43, 31, 38, 40, 48, 18, 17, 45, 16, 20, 14, 19, 51,
#        15, 11, 12, 47,  8, 44, 49,  4, 10, 13, 50,  9,  6], dtype=int64)

# %%
data["number vmail messages"].value_counts()
# Out:
# 0     3381
# 31      80
# 29      64
# 28      62
# 33      61
# 24      57
# 27      57
# 26      55
# 30      54
# 32      52
# 25      49
# 23      48
# 22      45
# 36      45
# 37      42
# 39      40
# 35      40
# 21      40
# 34      39
# 38      37
# 20      30
# 19      26
# 40      26
# 41      21
# 42      19
# 17      18
# 16      16
# 18      14
# 43      13
# 15      12
# 12      10
# 45      10
# 14       9
# 46       8
# 44       7
# 10       4
# 47       4
# 13       4
# 48       3
# 49       3
# 9        2
# 50       2
# 6        2
# 8        2
# 11       2
# 4        1
# 51       1
# Name: number vmail messages, dtype: int64

# %%
data["number vmail messages"].describe()
# Out:
# count    4617.000000
# mean        7.849903
# std        13.592333
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        17.000000
# max        51.000000
# Name: number vmail messages, dtype: float64

# %%
sns.distplot(data["number vmail messages"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='number vmail messages', ylabel='Density'>

# %%
fig=plt.figure(figsize=(10,8))
data.boxplot(column="number vmail messages",by="churn")
fig.suptitle("Number vmail message",fontsize=14,fontweight="bold")
plt.show()

# %%
data["customer service calls"].value_counts()
# Out:
# 1    1651
# 2    1031
# 0     951
# 3     616
# 4     234
# 5      89
# 6      28
# 7      13
# 9       2
# 8       2
# Name: customer service calls, dtype: int64

# %%
customer_service_calls_data = pd.crosstab(data["customer service calls"],data['churn'])
customer_service_calls_data["Percentage_Churn"] = customer_service_calls_data.apply(lambda x : x[1]*100/(x[0]+x[1]),axis = 1)
print(customer_service_calls_data)
# Out:
# churn                      0    1  Percentage_Churn
# customer service calls
# 0                        835  116         12.197687
# 1                       1475  176         10.660206
# 2                        919  112         10.863240
# 3                        551   65         10.551948
# 4                        130  104         44.444444
# 5                         34   55         61.797753
# 6                         10   18         64.285714
# 7                          6    7         53.846154
# 8                          1    1         50.000000
# 9                          0    2        100.000000

# %%
sns.countplot(x="customer service calls",hue="churn",data=data)
plt.show()
